# %% [markdown]
# # Test
# Test

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1,1,20)

def f(x):
    return x*x

plt.plot(x,f(x))

def g(x):
    return 2*x

plt.plot(x,g(x))

plt.grid("on")

#%matplotlib inline
#x = [1, 2, 3, 4, 5]
#y = [2, 4, 6, 8, 10]
 
#plt.plot(x, y)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Cool plot')
# Out:
# Text(0.5, 1.0, 'Cool plot')
